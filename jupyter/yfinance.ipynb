# %%
import yfinance as yf
dat = yf.Ticker("MSFT")

# %%
dat = yf.Ticker("MSFT")
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT241206C00240000 2024-11-21 14:40:22+00:00   240.0     175.58  190.75
# 1   MSFT241206C00250000 2024-11-29 15:19:59+00:00   250.0     171.89  180.75
# 2   MSFT241206C00300000 2024-11-21 17:47:15+00:00   300.0     131.28  130.60
# 3   MSFT241206C00305000 2024-11-22 17:59:31+00:00   305.0     110.24  125.80
# 4   MSFT241206C00310000 2024-11-25 20:54:40+00:00   310.0     109.80  120.80
# ..                  ...                       ...     ...        ...     ...
# 56  MSFT241206C00530000 2024-11-18 18:57:35+00:00   530.0       0.01    0.00
# 57  MSFT241206C00535000 2024-11-26 17:08:56+00:00   535.0       0.01    0.00
# 58  MSFT241206C00540000 2024-10-31 19:15:53+00:00   540.0       0.03    0.00
# 59  MSFT241206C00550000 2024-11-27 17:45:31+00:00   550.0       0.01    0.00
# 60  MSFT241206C00560000 2024-12-02 16:27:13+00:00   560.0       0.01    0.00
#
#        ask  change  percentChange  volume  openInterest  impliedVolatility  \
# 0   191.50    0.00       0.000000     NaN             1           1.593752
# 1   181.65    0.00       0.000000     3.0             3           1.769532
# 2   131.55   14.68      12.590052    30.0            35           1.496096
# 3   126.60    0.00       0.000000     7.0             7           1.167973
# 4   121.60    0.00       0.000000     1.0             2           1.117192
# ..     ...     ...            ...     ...           ...                ...
# 56    0.01    0.00       0.000000     6.0             7           0.546880
# 57    0.01    0.00       0.000000   500.0           502           0.562504
# 58    0.14    0.00       0.000000     NaN             7           0.750003
# 59    0.01    0.00       0.000000     1.0             4           0.625004
# 60    0.01    0.00       0.000000     1.0           106           0.671878
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# ..         ...          ...      ...
# 56       False      REGULAR      USD
# 57       False      REGULAR      USD
# 58       False      REGULAR      USD
# 59       False      REGULAR      USD
# 60       False      REGULAR      USD
#
# [61 rows x 14 columns]

# %%
tickers = yf.Tickers('MSFT AAPL GOOG')
display(tickers.tickers['MSFT'].info)
# yf.download(['MSFT', 'AAPL', 'GOOG'], period='1mo')
yf.download(['MSFT'], period='max')
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment offers server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 228000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 56,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 7869791,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 64,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2024,
#    'totalPay': 4755618,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 51,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'totalPay': 4704250,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 50,
#    'title': 'Executive VP & Chief Commercial Officer',
#    'yearBorn': 1973,
#    'fiscalYear': 2024,
#    'totalPay': 4534974,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 51,
#    'title': 'Executive Vice President of Business Development, Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'totalPay': 2993772,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Carolina  Dybeck Happe',
#    'age': 51,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 57,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 51,
#    'title': 'Executive VP of AI & CTO',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brett  Iversen',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Hossein  Nowbar',
#    'title': 'Chief Legal Officer',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 5,
#  'compensationRisk': 4,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 3,
#  'governanceEpochDate': 1733011200,
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 423.46,
#  'open': 421.54,
#  'dayLow': 421.31,
#  'dayHigh': 431.9,
#  'regularMarketPreviousClose': 423.46,
#  'regularMarketOpen': 421.54,
#  'regularMarketDayLow': 421.31,
#  'regularMarketDayHigh': 431.9,
#  'dividendRate': 3.32,
#  'dividendYield': 0.0078,
#  'exDividendDate': 1732147200,
#  'payoutRatio': 0.2477,
#  'fiveYearAvgDividendYield': 0.87,
#  'beta': 0.904,
#  'trailingPE': 35.599503,
#  'forwardPE': 28.663446,
#  'volume': 10326249,
#  'regularMarketVolume': 10326249,
#  'averageVolume': 19999807,
#  'averageVolume10days': 22166390,
#  'averageDailyVolume10Day': 22166390,
#  'bid': 430.68,
#  'ask': 431.44,
#  'bidSize': 100,
#  'askSize': 100,
#  'marketCap': 3205250940928,
#  'fiftyTwoWeekLow': 362.9,
#  'fiftyTwoWeekHigh': 468.35,
#  'priceToSalesTrailing12Months': 12.609666,
#  'fiftyDayAverage': 421.0552,
#  'twoHundredDayAverage': 422.03375,
#  'trailingAnnualDividendRate': 3.08,
#  'trailingAnnualDividendYield': 0.007273414,
#  'currency': 'USD',
#  'enterpriseValue': 3166783668224,
#  'profitMargins': 0.35608003,
#  'floatShares': 7424694989,
#  'sharesOutstanding': 7434880000,
#  'sharesShort': 56018482,
#  'sharesShortPriorMonth': 60313798,
#  'sharesShortPreviousMonthDate': 1728950400,
#  'dateShortInterest': 1731628800,
#  'sharesPercentSharesOut': 0.0075,
#  'heldPercentInsiders': 0.00056,
#  'heldPercentInstitutions': 0.73528,
#  'shortRatio': 2.58,
#  'shortPercentOfFloat': 0.0075,
#  'impliedSharesOutstanding': 7647889920,
#  'bookValue': 38.693,
#  'priceToBook': 11.141808,
#  'lastFiscalYearEnd': 1719705600,
#  'nextFiscalYearEnd': 1751241600,
#  'mostRecentQuarter': 1727654400,
#  'earningsQuarterlyGrowth': 0.107,
#  'netIncomeToCommon': 90511998976,
#  'trailingEps': 12.11,
#  'forwardEps': 14.95,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 12.458,
#  'enterpriseToEbitda': 23.191,
#  '52WeekChange': 0.1471529,
#  'SandP52WeekChange': 0.32005918,
#  'lastDividendValue': 0.83,
#  'lastDividendDate': 1732147200,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 431.11,
#  'targetHighPrice': 600.0,
#  'targetLowPrice': 420.0,
#  'targetMeanPrice': 504.89957,
#  'targetMedianPrice': 500.0,
#  'recommendationMean': 1.41818,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 48,
#  'totalCash': 78429003776,
#  'totalCashPerShare': 10.549,
#  'ebitda': 136551997440,
#  'totalDebt': 96838000640,
#  'quickRatio': 1.163,
#  'currentRatio': 1.301,
#  'totalRevenue': 254189993984,
#  'debtToEquity': 33.657,
#  'revenuePerShare': 34.202,
#  'returnOnAssets': 0.14592,
#  'returnOnEquity': 0.35604,
#  'freeCashflow': 61280874496,
#  'operatingCashflow': 122144997376,
#  'earningsGrowth': 0.104,
#  'revenueGrowth': 0.16,
#  'grossMargins': 0.69348997,
#  'ebitdaMargins': 0.53720003,
#  'operatingMargins': 0.46583998,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.2431}
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            MSFT        MSFT        MSFT        MSFT        MSFT
# Date
# 1986-03-13    0.059827    0.097222    0.101563    0.088542    0.088542
# 1986-03-14    0.061963    0.100694    0.102431    0.097222    0.097222
# 1986-03-17    0.063032    0.102431    0.103299    0.100694    0.100694
# 1986-03-18    0.061429    0.099826    0.103299    0.098958    0.102431
# 1986-03-19    0.060361    0.098090    0.100694    0.097222    0.099826
# ...                ...         ...         ...         ...         ...
# 2024-11-25  418.790009  418.790009  421.079987  414.850006  418.380005
# 2024-11-26  427.989990  427.989990  429.040009  418.850006  419.589996
# 2024-11-27  422.989990  422.989990  427.230011  422.019989  425.109985
# 2024-11-29  423.459991  423.459991  424.880005  417.799988  420.089996
# 2024-12-02  431.109985  431.109985  431.899994  421.309998  421.540009
#
# Price           Volume
# Ticker            MSFT
# Date
# 1986-03-13  1031788800
# 1986-03-14   308160000
# 1986-03-17   133171200
# 1986-03-18    67766400
# 1986-03-19    47894400
# ...                ...
# 2024-11-25    27691100
# 2024-11-26    23458900
# 2024-11-27    18332400
# 2024-11-29    16271900
# 2024-12-02    10326249
#
# [9759 rows x 6 columns]

# %%
spy = yf.Ticker('SPY').funds_data
display(spy.description)
display(spy.top_holdings)
# Out:
# 'The Trust seeks to achieve its investment objective by holding a portfolio of the common stocks that are included in the index (the “Portfolio”), with the weight of each stock in the Portfolio substantially corresponding to the weight of such stock in the index.'
#                                   Name  Holding Percent
# Symbol
# AAPL                         Apple Inc         0.071161
# NVDA                       NVIDIA Corp         0.067663
# MSFT                    Microsoft Corp         0.062576
# AMZN                    Amazon.com Inc         0.036076
# META        Meta Platforms Inc Class A         0.025691
# GOOGL             Alphabet Inc Class A         0.020771
# GOOG              Alphabet Inc Class C         0.017184
# BRK-B   Berkshire Hathaway Inc Class B         0.017113
# AVGO                      Broadcom Inc         0.016373
# TSLA                         Tesla Inc         0.014362

# %%
# read tickers from company_tickers.json
import json
with open('company_tickers.json') as f:
    data = json.load(f)
    tickers = list(data.values())
    tickers = [t['ticker'] for t in tickers]

display("Total tickers: ", len(tickers))
display(tickers)
# Out:
# 'Total tickers: '
# 10016
# ['NVDA',
#  'AAPL',
#  'MSFT',
#  'AMZN',
#  'GOOGL',
#  'META',
#  'TSLA',
#  'BRK-B',
#  'TSM',
#  'AVGO',
#  'LLY',
#  'WMT',
#  'JPM',
#  'V',
#  'UNH',
#  'SPY',
#  'ORCL',
#  'XOM',
#  'MA',
#  'NVO',
#  'COST',
#  'PG',
#  'HD',
#  'NFLX',
#  'JNJ',
#  'BAC',
#  'CRM',
#  'ABBV',
#  'RCIT',
#  'CVX',
#  'SAP',
#  'TMUS',
#  'KO',
#  'ASML',
#  'WFC',
#  'MRK',
#  'BX',
#  'CSCO',
#  'TM',
#  'ACN',
#  'AMD',
#  'ADBE',
#  'PEP',
#  'MS',
#  'NOW',
#  'LIN',
#  'DIS',
#  'NVS',
#  'AXP',
#  'MCD',
#  'IBM',
#  'BABA',
#  'PM',
#  'ABT',
#  'SHEL',
#  'AZN',
#  'QQQ',
#  'TMO',
#  'ISRG',
#  'GE',
#  'INTU',
#  'CAT',
#  'GS',
#  'TXN',
#  'VZ',
#  'RY',
#  'QCOM',
#  'BKNG',
#  'DHR',
#  'HSBC',
#  'CMCSA',
#  'T',
#  'HDB',
#  'RTX',
#  'NEE',
#  'SPGI',
#  'FMX',
#  'AMGN',
#  'PGR',
#  'BLK',
#  'LOW',
#  'SCHW',
#  'SYK',
#  'ETN',
#  'HON',
#  'UBER',
#  'AMAT',
#  'KKR',
#  'UNP',
#  'PDD',
#  'UL',
#  'PFE',
#  'PLTR',
#  'ARM',
#  'SHOP',
#  'MUFG',
#  'TTE',
#  'BSX',
#  'TJX',
#  'BHP',
#  'C',
#  'PANW',
#  'COP',
#  'LMT',
#  'ANET',
#  'FI',
#  'ADP',
#  'RTNTF',
#  'SNY',
#  'DE',
#  'BMY',
#  'SONY',
#  'VRTX',
#  'EADSY',
#  'CB',
#  'MU',
#  'SBUX',
#  'UPS',
#  'NKE',
#  'GILD',
#  'MMC',
#  'BUD',
#  'MDT',
#  'BA',
#  'APP',
#  'ADI',
#  'INTC',
#  'PLD',
#  'IBN',
#  'UBS',
#  'RIO',
#  'MSTR',
#  'MELI',
#  'TD',
#  'DELL',
#  'AIQUY',
#  'SO',
#  'SHW',
#  'GEV',
#  'MO',
#  'SPOT',
#  'AMT',
#  'ENB',
#  'LRCX',
#  'TT',
#  'APO',
#  'ELV',
#  'SMFG',
#  'CI',
#  'INFY',
#  'PH',
#  'ICE',
#  'CTAS',
#  'EQIX',
#  'WM',
#  'DUK',
#  'PBR',
#  'APH',
#  'CRWD',
#  'BN',
#  'MDLZ',
#  'MCO',
#  'WELL',
#  'SNPS',
#  'PYPL',
#  'RELX',
#  'KLAC',
#  'CDNS',
#  'HCA',
#  'ABNB',
#  'AON',
#  'MSI',
#  'REGN',
#  'PNC',
#  'CME',
#  'BTI',
#  'IBKR',
#  'USB',
#  'MRVL',
#  'ITW',
#  'ZTS',
#  'MCK',
#  'CMG',
#  'SCCO',
#  'MAR',
#  'CEG',
#  'CFRUY',
#  'RACE',
#  'GD',
#  'BP',
#  'CL',
#  'COIN',
#  'EOG',
#  'EMR',
#  'APD',
#  'CNQ',
#  'WMB',
#  'TRI',
#  'SHECY',
#  'SAN',
#  'NOC',
#  'FDX',
#  'DASH',
#  'FTNT',
#  'CVS',
#  'WDAY',
#  'EPD',
#  'BNPQY',
#  'TDG',
#  'CP',
#  'COF',
#  'BNS',
#  'MMM',
#  'ORLY',
#  'BMO',
#  'ECL',
#  'CARR',
#  'GSK',
#  'SPG',
#  'CNI',
#  'CRH',
#  'EQNR',
#  'ADSK',
#  'OKE',
#  'CSX',
#  'RSG',
#  'SE',
#  'TOELY',
#  'AJG',
#  'TEAM',
#  'DEO',
#  'BDX',
#  'ET',
#  'NU',
#  'GLD',
#  'RCL',
#  'MFG',
#  'KMI',
#  'DLR',
#  'TTD',
#  'FCX',
#  'SLB',
#  'ANZGY',
#  'TFC',
#  'AFL',
#  'CM',
#  'NGG',
#  'HLT',
#  'GM',
#  'PCAR',
#  'SRE',
#  'NSC',
#  'MBGYY',
#  'TRV',
#  'PSA',
#  'ROP',
#  'MET',
#  'GLNCY',
#  'GWW',
#  'SQ',
#  'MFC',
#  'BK',
#  'JD',
#  'NXPI',
#  'SNOW',
#  'NTES',
#  'FICO',
#  'VST',
#  'JCI',
#  'BBVA',
#  'AMP',
#  'PCG',
#  'TGT',
#  'URI',
#  'CHTR',
#  'ARES',
#  'CPRT',
#  'PSX',
#  'GBTC',
#  'PTCAY',
#  'ITUB',
#  'VRT',
#  'ALL',
#  'FANG',
#  'MNST',
#  'DHI',
#  'TRP',
#  'SU',
#  'AEP',
#  'AZO',
#  'MPC',
#  'PAYX',
#  'CMI',
#  'BAESY',
#  'LNG',
#  'O',
#  'PWR',
#  'CTA-PA',
#  'ING',
#  'MPLX',
#  'NEM',
#  'DDOG',
#  'D',
#  'IAU',
#  'WCN',
#  'OXY',
#  'BCS',
#  'COR',
#  'AXON',
#  'HWM',
#  'FLUT',
#  'AIG',
#  'FAST',
#  'ROST',
#  'LHX',
#  'CODYY',
#  'ODFL',
#  'AMX',
#  'NDAQ',
#  'FIS',
#  'KVUE',
#  'PEG',
#  'KMB',
#  'HES',
#  'ATEYY',
#  'MSCI',
#  'CCI',
#  'E',
#  'LEN',
#  'AME',
#  'TRGP',
#  'PRU',
#  'TEL',
#  'VLO',
#  'BKR',
#  'BMWKY',
#  'DFS',
#  'EA',
#  'KDP',
#  'STZ',
#  'HLN',
#  'DNZOY',
#  'CPNG',
#  'F',
#  'TAK',
#  'CRARY',
#  'SVNDY',
#  'TCOM',
#  'NWG',
#  'KR',
#  'VALE',
#  'ALC',
#  'LYG',
#  'CTVA',
#  'AEM',
#  'IR',
#  'EW',
#  'DAL',
#  'FERG',
#  'GLW',
#  'HMC',
#  'CAIXY',
#  'XEL',
#  'CBRE',
#  'IMO',
#  'VRSK',
#  'GRMN',
#  'OTIS',
#  'IT',
#  'EXC',
#  'CTSH',
#  'LULU',
#  'WTKWY',
#  'A',
#  'STLA',
#  'OLCLY',
#  'GEHC',
#  'KHC',
#  'YUM',
#  'HUBS',
#  'VMC',
#  'ACGL',
#  'EXR',
#  'SYY',
#  'OWL',
#  'HPQ',
#  'LVS',
#  'PPERY',
#  'MLM',
#  'MTB',
#  'CCEP',
#  'MCHP',
#  'DIA',
#  'IQV',
#  'HUM',
#  'RMD',
#  'SLF',
#  'NET',
#  'WIT',
#  'HSY',
#  'GIS',
#  'NUE',
#  'DKILY',
#  'ARGX',
#  'IRM',
#  'TPL',
#  'HIG',
#  'DD',
#  'VEEV',
#  'VICI',
#  'CCL',
#  'IDXX',
#  'WAB',
#  'ED',
#  'ABEV',
#  'EIX',
#  'RJF',
#  'MDY',
#  'HEI',
#  'GWLIF',
#  'DB',
#  'AVB',
#  'TTWO',
#  'ETR',
#  'RBLX',
#  'BSBR',
#  'LYV',
#  'FCNCA',
#  'FRFHF',
#  'ANYYY',
#  'ALNY',
#  'ZS',
#  'HOOD',
#  'BRO',
#  'FITB',
#  'WEC',
#  'WTW',
#  'CSGP',
#  'GOLD',
#  'ROK',
#  'QSR',
#  'DOW',
#  'MRAAY',
#  'EFX',
#  'UAL',
#  'WDS',
#  'XYL',
#  'DSCSY',
#  'ANSS',
#  'IOT',
#  'CNC',
#  'CVE',
#  'CAH',
#  'GPN',
#  'EBAY',
#  'CHT',
#  'KEYS',
#  'EQR',
#  'DXCM',
#  'TW',
#  'ON',
#  'TSCO',
#  'CVNA',
#  'SW',
#  'CUK',
#  'WPM',
#  'BIDU',
#  'PPG',
#  'HPE',
#  'STT',
#  'HAL',
#  'EQT',
#  'K',
#  'DOV',
#  'FER',
#  'MPWR',
#  'NVR',
#  'CHD',
#  'DECK',
#  'RKT',
#  'VTR',
#  'AWK',
#  'GDDY',
#  'ERIC',
#  'PPRUY',
#  'LYB',
#  'OEZVY',
#  'FTV',
#  'RDDT',
#  'BR',
#  'PUBGY',
#  'PHM',
#  'NVZMY',
#  'TROW',
#  'KB',
#  'VLTO',
#  'CCJ',
#  'CPAY',
#  'NTAP',
#  'CQP',
#  'HBAN',
#  'TYL',
#  'BNTX',
#  'PPL',
#  'DTE',
#  'TPG',
#  'ADM',
#  'DVN',
#  'FUJIY',
#  'TEF',
#  'SYF',
#  'WBD',
#  'GIB',
#  'FANUY',
#  'MTD',
#  'PBA',
#  'AEE',
#  'ZM',
#  'HUBB',
#  'BEKE',
#  'IX',
#  'SMPNY',
#  'PHG',
#  'NTDTY',
#  'LPLA',
#  'EME',
#  'LI',
#  'RF',
#  'CINF',
#  'FE',
#  'BCE',
#  'TOST',
#  'TECK',
#  'EL',
#  'ROL',
#  'CDW',
#  'BBD',
#  'WRB',
#  'FNV',
#  'SBAC',
#  'RYAAY',
#  'EXPE',
#  'GFS',
#  'BAM',
#  'MDB',
#  'LII',
#  'ATO',
#  'PTC',
#  'WST',
#  'NTR',
#  'VOD',
#  'BIIB',
#  'DIDIY',
#  'EXE',
#  'IFF',
#  'ES',
#  'TU',
#  'GRAB',
#  'WDC',
#  'TSN',
#  'NOK',
#  'HDELY',
#  'STLD',
#  'TDY',
#  'NTRA',
#  'WY',
#  'FTS',
#  'LDOS',
#  'ERIE',
#  'MKL',
#  'STM',
#  'CBOE',
#  'PKG',
#  'WSO',
#  'WAT',
#  'NJDCY',
#  'ZBH',
#  'BGNE',
#  'NTRS',
#  'ILMN',
#  'DKNG',
#  'SYM',
#  'PUK',
#  'ASX',
#  'STE',
#  'WSM',
#  'STX',
#  'UI',
#  'CLX',
#  'MKC',
#  'KSPI',
#  'FOXA',
#  'CFG',
#  'INVH',
#  'AFRM',
#  'IP',
#  'CMS',
#  'CNP',
#  'TS',
#  'EJPRY',
#  'ZBRA',
#  'BLDR',
#  'ESS',
#  'SHG',
#  'CTRA',
#  'LH',
#  'CSL',
#  'MT',
#  'CHKP',
#  'CJPRY',
#  'COO',
#  'OMC',
#  'FSLR',
#  'PINS',
#  'NRG',
#  'IHG',
#  'VIK',
#  'YAHOY',
#  'PFG',
#  'DRI',
#  'TEVA',
#  'TRU',
#  'LUV',
#  'RCI',
#  'KEY',
#  'BAH',
#  'BF-A',
#  'ZG',
#  'NTNX',
#  'TME',
#  'MAA',
#  'SNA',
#  'CG',
#  'BBY',
#  'RYAN',
#  'SSNC',
#  'AER',
#  'ARE',
#  'PODD',
#  'GEN',
#  'L',
#  'SGSOY',
#  'FDS',
#  'DGX',
#  'JBHT',
#  'HOLX',
#  'ONON',
#  'NMR',
#  'BALL',
#  'GFL',
#  'FTAI',
#  'YUMC',
#  'CRBG',
#  'SNAP',
#  'VRSN',
#  'NI',
#  'RBA',
#  'PNR',
#  'RPM',
#  'TRMB',
#  'FIX',
#  'XPO',
#  'ICLR',
#  'IEX',
#  'UMC',
#  'BURL',
#  'RS',
#  'TER',
#  'NWSA',
#  'SMCI',
#  'ALGN',
#  'MOH',
#  'TLK',
#  'KIM',
#  'KOF',
#  'SUI',
#  'PSTG',
#  'OC',
#  'GPC',
#  'MAS',
#  'UDR',
#  'EXPD',
#  'ALAB',
#  'BEP',
#  'EC',
#  'J',
#  'SOFI',
#  'BAX',
#  'GWRE',
#  'HRL',
#  'MANH',
#  'ZTO',
#  'EG',
#  'FNF',
#  'PKX',
#  'WLK',
#  'CAVA',
#  'COHR',
#  'UTHR',
#  'DOCU',
#  'WMG',
#  'DG',
#  'LNT',
#  'BIP',
#  'DKS',
#  'MRO',
#  'AVY',
#  'LINE',
#  'FLEX',
#  'ULTA',
#  'JEF',
#  'ENTG',
#  'AMH',
#  'CF',
#  'VTRS',
#  'BAP',
#  'USFD',
#  'DT',
#  'AZPN',
#  'RPRX',
#  'TWLO',
#  'TXT',
#  'TOL',
#  'YPF',
#  'DPZ',
#  'JHX',
#  'DOC',
#  'CASY',
#  'ACM',
#  'GGG',
#  'RGA',
#  'EDPFY',
#  'BZLFY',
#  'AMCR',
#  'CNH',
#  'H',
#  'DUOL',
#  'EWBC',
#  'KKPNY',
#  'EVRG',
#  'NDSN',
#  'JBL',
#  'EQH',
#  'MORN',
#  'SFM',
#  'SAIA',
#  'MRNA',
#  'CHWY',
#  'WLMIY',
#  'BSY',
#  'WES',
#  'BXP',
#  'FFIV',
#  'VIV',
#  'CYBR',
#  'ELS',
#  'THC',
#  'ARCC',
#  'DLTR',
#  'MBLY',
#  'CW',
#  'AGR',
#  'SN',
#  'POOL',
#  'GLPI',
#  'EPAM',
#  'AVTR',
#  'UNM',
#  'MNDY',
#  'SMMT',
#  'RNR',
#  'REG',
#  'SWKS',
#  'SWK',
#  'AKAM',
#  'GFI',
#  'INCY',
#  'CLH',
#  'RVTY',
#  'PFGC',
#  'OMVKY',
#  'DVA',
#  'CNA',
#  'JBSAY',
#  'HLI',
#  'LAMR',
#  'CPB',
#  'TPR',
#  'INSM',
#  'FMS',
#  'PAYC',
#  'GMAB',
#  'CPT',
#  'UHS',
#  'OKTA',
#  'CAG',
#  'SUZ',
#  'TXRH',
#  'NVT',
#  'RTO',
#  'PR',
#  'ALB',
#  'CHRW',
#  'RL',
#  'JBAXY',
#  'FTI',
#  'HST',
#  'NNGRY',
#  'ITT',
#  'MGA',
#  'JKHY',
#  'NBIX',
#  'KMX',
#  'APTV',
#  'TFII',
#  'PAA',
#  'WPC',
#  'SCI',
#  'GME',
#  'TAP',
#  'LBRDA',
#  'PPC',
#  'BJ',
#  'SSMXY',
#  'BG',
#  'KGC',
#  'DAY',
#  'ALLE',
#  'JLL',
#  'OVV',
#  'BWXT',
#  'RKUNY',
#  'JPXGY',
#  'AFG',
#  'MMYT',
#  'SOLV',
#  'LOGI',
#  'BMRN',
#  'SJM',
#  'AS',
#  'EBR',
#  'EMN',
#  'AA',
#  'WIX',
#  'XPEV',
#  'EVR',
#  'UHAL',
#  'SF',
#  'JNPR',
#  'LECO',
#  'BCH',
#  'FUTU',
#  'RDY',
#  'NCLH',
#  'RRX',
#  'GMED',
#  'AIZ',
#  'FND',
#  'BEN',
#  'SGIOY',
#  'ALLY',
#  'KNSL',
#  'SBS',
#  'ATR',
#  'MGM',
#  'MTZ',
#  'TECH',
#  'PCTY',
#  'PCOR',
#  'TLN',
#  'HTHT',
#  'ESLT',
#  'OHI',
#  'PCVX',
#  'WPP',
#  'VDMCY',
#  'POAHY',
#  'RKLB',
#  'NDEKY',
#  'ACI',
#  'AAON',
#  'CUBE',
#  'TKO',
#  'NLY',
#  'HLNE',
#  'KEP',
#  'TKHVY',
#  'GNRC',
#  'TTEK',
#  'CART',
#  'SNN',
#  'COKE',
#  'LW',
#  'EMRAF',
#  'CCK',
#  'NICE',
#  'SQM',
#  'PTBRY',
#  'CTLT',
#  'WTRG',
#  'MUSA',
#  'CLS',
#  'PAG',
#  'IPG',
#  'BLD',
#  'FHN',
#  'CACI',
#  'PSN',
#  'ULS',
#  'PRMB',
#  'AOS',
#  'ARMK',
#  'MEDP',
#  'PNW',
#  'SMKUY',
#  'SRPT',
#  'DTM',
#  'BPYPP',
#  'AUR',
#  'AU',
#  'MLI',
#  'RIVN',
#  'CHDN',
#  'CR',
#  'AIT',
#  'HNGKY',
#  'AR',
#  'SEIC',
#  'WBS',
#  'VNOM',
#  'GTLB',
#  'WWD',
#  'EXP',
#  'AEG',
#  'KIKOY',
#  'ALSN',
#  'CSXXY',
#  'WCC',
#  'RBC',
#  'LAD',
#  'APG',
#  'ALSMY',
#  'PSO',
#  'WAL',
#  'WMS',
#  'YMM',
#  'ROKU',
#  'EHC',
#  'WYNN',
#  'CRRFY',
#  'SNX',
#  'EXAS',
#  'AYI',
#  'PRI',
#  'EXEL',
#  'UWMC',
#  'CIEN',
#  'NIO',
#  'CRL',
#  'LKQ',
#  'CFLT',
#  'BRBR',
#  'DSGX',
#  'WING',
#  'KVYO',
#  'KAIKY',
#  'FOUR',
#  'STN',
#  'FRT',
#  'MKTX',
#  'REXR',
#  'DOX',
#  'RGLD',
#  'SARO',
#  'ORI',
#  'RVMD',
#  'SLV',
#  'ESTC',
#  'MTSI',
#  'GLOB',
#  'UUGRY',
#  'PNFP',
#  'RDEIY',
#  'EDU',
#  'DRS',
#  'AAL',
#  'INGR',
#  'TPX',
#  'FBIN',
#  'FLR',
#  'QGEN',
#  'AES',
#  'PAC',
#  'BILL',
#  'CBSH',
#  'VFS',
#  'BSAC',
#  'DSEEY',
#  'PEN',
#  'HQY',
#  ...]

# %%
industries = {}

# get industry for first 10 tickers
for ticker in tickers[:10]:
    ticker_info = yf.Ticker(ticker).info
    industries[ticker] = ticker_info.get('industry', 'N/A')

display(industries)
# Out:
# {'NVDA': 'Semiconductors',
#  'AAPL': 'Consumer Electronics',
#  'MSFT': 'Software - Infrastructure',
#  'AMZN': 'Internet Retail',
#  'GOOGL': 'Internet Content & Information',
#  'META': 'Internet Content & Information',
#  'TSLA': 'Auto Manufacturers',
#  'BRK-B': 'Insurance - Diversified',
#  'TSM': 'Semiconductors',
#  'AVGO': 'Semiconductors'}
